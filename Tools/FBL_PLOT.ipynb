# %%
import sys, os, struct

import numpy as np   
import matplotlib.pyplot as plt

# %%
sys.path.append('/Users/Hao/mylibrary/FBL/')
import FBL_TOOL as ft

# %%
path = '/Volumes/Codes/Underdevelopment/FBL_INVERSION/syn/'
res1 = ft.readresult(path+'res')

print(res1.keys())
# Out:
# dict_keys(['check', 'Ny', 'Nz', 'Nstk', 'Nline', 'Lines', 'NThom', 'Thoms', 'FOV', 'nspec', 'Nys', 'Nzs', 'FOVSPEC', 'prof'])

# %%
fig = plt.figure(1, figsize=(12,12))
fig.subplots_adjust(left=0.1, bottom=0.1, right=0.90, top=0.9, wspace=0.15, hspace=0.15)


ax1 = fig.add_subplot(331)
im1 = ax1.imshow(res1['Lines'][0]['data'][0,:,:],cmap='seismic')
fig.colorbar(im1, ax=ax1, shrink=0.6)


ax2 = fig.add_subplot(332)
im2 = ax2.imshow(res1['Lines'][0]['data'][1,:,:],cmap='seismic')
fig.colorbar(im2, ax=ax2, shrink=0.6)


ax3 = fig.add_subplot(333)
im3 =  ax3.imshow(res1['Lines'][0]['data'][2,:,:],cmap='seismic')
fig.colorbar(im3, ax=ax3, shrink=0.6)


ax4 = fig.add_subplot(334)
im4 = ax4.imshow(res1['Lines'][1]['data'][0,:,:],cmap='seismic')
fig.colorbar(im4, ax=ax4, shrink=0.6)


ax5 = fig.add_subplot(335)
im5 = ax5.imshow(res1['Lines'][1]['data'][1,:,:],cmap='seismic')
fig.colorbar(im5, ax=ax5, shrink=0.6)


ax6 = fig.add_subplot(336)
im6 = ax6.imshow(res1['Lines'][1]['data'][2,:,:],cmap='seismic')
fig.colorbar(im6, ax=ax6, shrink=0.6)


ax7 = fig.add_subplot(337)
im7 = ax7.imshow((res1['Thoms'][0]['data'][0,:,:]),cmap='seismic')
fig.colorbar(im7, ax=ax7, shrink=0.6)

ax8 = fig.add_subplot(338)
im8 = ax8.imshow((res1['Thoms'][1]['data'][0,:,:]),cmap='seismic')
fig.colorbar(im8, ax=ax8, shrink=0.6)

ax9 = fig.add_subplot(339)
im9 = ax9.imshow((res1['Thoms'][1]['data'][1,:,:]),cmap='seismic')
fig.colorbar(im9, ax=ax9, shrink=0.6)

'''
ax4 = fig.add_subplot(234)
im4 = ax4.imshow(res1[3,:,:])
fig.colorbar(im4, ax=ax4)


ax5 = fig.add_subplot(235)
im5 = ax5.imshow(res1[4,:,:])
fig.colorbar(im5, ax=ax5)

ax6 = fig.add_subplot(236)
im6 = ax6.imshow(np.sqrt(res1[4,:,:]*res1[4,:,:]+res1[3,:,:]*res1[3,:,:]))
fig.colorbar(im6, ax=ax6)
'''
plt.show()

# %%
fig = plt.figure(1, figsize=(10,10))
fig.subplots_adjust(left=0.1, bottom=0.1, right=0.90, top=0.9, wspace=0.15, hspace=0.15)


iline = 0
iz = 20
iy = 20

ax1 = fig.add_subplot(411)

ax1.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,0,iz,iy])

ax2 = fig.add_subplot(412)


ax2.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,1,iz,iy])

ax3 = fig.add_subplot(413)

ax3.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,2,iz,iy])

ax4 = fig.add_subplot(414)

ax4.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,3,iz,iy])

#print(hdu[2].data)
plt.show()

# %%
fig = plt.figure(1, figsize=(10,10))
fig.subplots_adjust(left=0.1, bottom=0.1, right=0.90, top=0.9, wspace=0.15, hspace=0.15)


iline = 1
iz = 20
iy = 20

ax1 = fig.add_subplot(411)

ax1.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,0,iz,iy])

ax2 = fig.add_subplot(412)


ax2.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,1,iz,iy])

ax3 = fig.add_subplot(413)

ax3.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,2,iz,iy])

ax4 = fig.add_subplot(414)

ax4.plot(res1['prof'][iline]['L'], res1['prof'][iline]['prof'][:,3,iz,iy])

#print(hdu[2].data)
plt.show()
